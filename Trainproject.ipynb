# %%
#Step1
from sklearn.linear_model import LogisticRegression
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#Step 2
data =  pd.read_csv("./Program/csv_files/train.csv")
data
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18732\974247087.py:2: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   data =  pd.read_csv("./Program/csv_files/train.csv")
#             ID Customer_ID     Month           Name   Age          SSN  \
# 0       0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265
# 1       0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265
# 2       0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265
# 3       0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265
# 4       0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265
# ...        ...         ...       ...            ...   ...          ...
# 99995  0x25fe9  CUS_0x942c     April          Nicks    25  078-73-5990
# 99996  0x25fea  CUS_0x942c       May          Nicks    25  078-73-5990
# 99997  0x25feb  CUS_0x942c      June          Nicks    25  078-73-5990
# ...

# %%
#Step 3I
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  object
#  1   Customer_ID               100000 non-null  object
#  2   Month                     100000 non-null  object
#  3   Name                      90015 non-null   object
#  4   Age                       100000 non-null  object
#  5   SSN                       100000 non-null  object
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  object
#  8   Monthly_Inhand_Salary     84998 non-null   float64
#  9   Num_Bank_Accounts         100000 non-null  int64
#  10  Num_Credit_Card           100000 non-null  int64
#  11  Interest_Rate             100000 non-null  int64
#  12  Num_of_Loan               100000 non-null  object
# ...

# %%
print('ID', data['ID'].unique())
print(data['Customer_ID'].unique())
print(data['Month'].unique())
print(data['Name'].unique())
print(data['Age'].unique())
print(data['SSN'].unique())
print(data['Occupation'].unique())
print(data['Annual Income'].unique())
print(data['Num_of_Loan'].unique())
print(data['Type_of_Loan'].unique())
print(data['Num_of_Delayed_Payment'].unique())
print(data['Changed_Credit_Limit '].unique())
print(data['Credit_Mix'].unique())
print(data['Outstanding_Debt'].unique())
print(data['Monthly_Balance'].unique())
print(data['Credit_Score'].unique())
# print(data['ID'].unique())
# print(data['ID'].unique())
# print(data['ID'].unique())
# print(data['ID'].unique())
# Out:
# ID ['0x1602' '0x1603' '0x1604' ... '0x25feb' '0x25fec' '0x25fed']
# ['CUS_0xd40' 'CUS_0x21b1' 'CUS_0x2dbc' ... 'CUS_0xaf61' 'CUS_0x8600'
#  'CUS_0x942c']
# ['January' 'February' 'March' 'April' 'May' 'June' 'July' 'August']
# ['Aaron Maashoh' nan 'Rick Rothackerj' ... 'Chris Wickhamm'
#  'Sarah McBridec' 'Nicks']
# ['23' '-500' '28_' ... '4808_' '2263' '1342']
# ['821-00-0265' '#F%$D@*&8' '004-07-5839' ... '133-16-7738' '031-35-0942'
#  '078-73-5990']
# ['Scientist' '_______' 'Teacher' 'Engineer' 'Entrepreneur' 'Developer'
#  'Lawyer' 'Media_Manager' 'Doctor' 'Journalist' 'Manager' 'Accountant'
#  'Musician' 'Mechanic' 'Writer' 'Architect']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File e:\NCCS\5th Sem\Python\Install\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# ...
